# %% [markdown]
# # Goal
#
#
# **Some business Objectives:**
#
# - Retain customers
# - Analyze relevant customer data
# - Develop focused customer retention programs
#
#
# ## Instructions
# 1. Import the necessary libraries.
# 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.
# 3. First look at its main features (head, shape, info).
# 4. Rename the columns so they follow the PE8 (snake case).
# 5. Change effective to date column to datetime format.
# 6. Check NaN values per column.
# 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.
# 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.
# 9. Get categorical features.
# 10. What should we do with the customer_id column?

# %%
# 1. Import the necessary libraries.
# 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.
import pandas as pd
import numpy as np
infile = 'we_fn_use_c_marketing_customer_value_analysis.csv'
customer_df = pd.read_csv(infile)
pd.set_option('display.max_columns', None)          # view all columns in jupyter
pd.set_option('display.max_rows', 150)                 # view max rows in jupyter

# %%
# 3. First look at its main features (head, shape, info).
# customer_df.head()
# customer_df.shape
# customer_df.info
customer_df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# dtype: object

# %%
# 4. Rename the columns so they follow the PEP8 (snake case).
customer_df.columns = customer_df.columns.map(lambda x : x.replace("-", "_").replace(" ", "_").lower())
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
# 10. What should we do with the customer_id column?
# Drop it (earlier in the process)
customer_df = customer_df.drop(['customer'], axis = 1)
customer_df.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
# 5. Change effective to date column to datetime format.
customer_df['effective_to_date']= pd.to_datetime(customer_df['effective_to_date'])
customer_df['effective_to_date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# 6. Check NaN values per column.
customer_df[customer_df.isna().any(axis=1)]   #or
customer_df.isnull().sum()/len(customer_df)
# Out:
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64

# %%
customer_df['income'].nunique()
# Out:
# 5694

# %%
# 7. Define a function that differentiates between continuous variables (by measuring) and 
# discrete variables (by counting). Hint: A number of unique values might be useful. 
# Store continuous data into a continuous data and do the same for discrete and categorical.
# This question is not very clear: what output is expected?
# assumption: customer_df split up in 3:
# df continuous  = customer_df_con
# df discrete    = customer_df_dis
# df categorical = customer_df_cat

def cat_types(cols):
    list_cols = customer_df.columns.tolist()
    for x in cols:
        thres = 10         # when classes/categories/discrete are expected
        type = customer_df[x].dtypes
        if type == 'object':
            cat_lst.append(x)
        elif type == 'datetime64[ns]' and customer_df[x].nunique() > thres:
            con_lst.append(x)
        elif type == 'int64' and customer_df[x].nunique() < thres:
            dis_lst.append(x)
        else:
            con_lst.append(x)     
    return con_lst, dis_lst, cat_lst

# Calling the function
con_lst = []
dis_lst = []
cat_lst = []
cat_types(customer_df)              # returns list with array of columns
customer_cat = customer_df[cat_lst]
customer_dis = customer_df[dis_lst]
customer_con = customer_df[con_lst]

display(customer_con.head(1))
display(customer_dis.head(1))
display(customer_cat.head(1))
# Out:
#    customer_lifetime_value effective_to_date  income  monthly_premium_auto  \
# 0              2763.519279        2011-02-24   56274                    69
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
#    number_of_open_complaints  number_of_policies
# 0                          0                   1
#         state response coverage education employmentstatus gender  \
# 0  Washington       No    Basic  Bachelor         Employed      F
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
#
#   sales_channel vehicle_class vehicle_size
# 0         Agent  Two-Door Car      Medsize

# %%
# 8. For the categorical data, check if there is some kind of text in a variable so we would 
# need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, 
# decide what to do with the variables you get.
# a. visualize value counts
# b. draw conclusions and make decision
# c. clean

# %%
# a. visualize value counts
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
for c in customer_cat:
    plt.figure(figsize=(10,5))
    plt.bar(customer_cat[c].unique(), customer_cat[c].value_counts())
    plt.title(c)
    plt.show();

# %%
# b. draw conclusions and make decision
# Education - merge last one with master as "master or higher"
# Employed - only this and non-working
# Suburban - non-suburban
# Married - non-married
# corporate Auto - non-corporate auto
# Policy: personal - non-personal
# vehicle class: combine last 3 into luxury

# %%
# c. clean
import warnings
warnings.filterwarnings("ignore")

# Education - merge last two into "master or higher"
def clean_education_col(x):
    if x in ['Doctor','Master']:
        return 'Master or Higher'
    else:
        return x

customer_cat['education'] = customer_cat['education'].apply(clean_education_col)

# %%
# c. clean

# employmentstatus - only this and non-working
def clean_employment_col(x):
    if x in ['Unemployed','Medical Leave','Disabled','Retired']:
        return 'Inactives'
    else:
        return x

customer_cat['employmentstatus'] = customer_cat['employmentstatus'].apply(clean_employment_col)

# %%
# c. clean

# Suburban - non-suburban
def clean_loc_code_col(x):
    if x in ['Rural','Urban']:
        return 'Non-suburban'
    else:
        return x

customer_cat['location_code'] = customer_cat['location_code'].apply(clean_loc_code_col)

# %%
# c. clean

# marital_status - Married - non-married
def clean_mer_status_col(x):
    if x in ['Single','Divorced']:
        return 'Not married'
    else:
        return x

customer_cat['marital_status'] = customer_cat['marital_status'].apply(clean_mer_status_col)

# %%
# c. clean

# Personal / corporate Auto special
def clean_policy_t_col(x):
    if x in ['Corporate Auto','Special Auto']:
        return 'Corporate/special'
    else:
        return x

customer_cat['policy_type'] = customer_cat['policy_type'].apply(clean_policy_t_col)

# %%
# c. clean

# Policy: personal - non-personal
def clean_policy_col(x):
    if x in ['Corporate L3','Corporate L2','Corporate L1','Special L3','Special L2','Special L1']:
        x = x.replace("Corporate","Non-personal")
        x = x.replace("Special","Non-personal")
        return x
    else:
        return x

customer_cat['policy'] = customer_cat['policy'].apply(clean_policy_col)

# %%
# c. clean

# vehicle class: combine last 3 into luxury
def clean_vehicle_c_col(x):
    if x in ['Sports Car','Luxury SUV','Luxury Car']:
        return 'Sports/luxury'
    else:
        return x

customer_cat['vehicle_class'] = customer_cat['vehicle_class'].apply(clean_vehicle_c_col)

# %%
customer_cat['policy'].value_counts()
# Out:
# Personal L3        3426
# Personal L2        2122
# Personal L1        1240
# Non-personal L3    1162
# Non-personal L2     759
# Non-personal L1     425
# Name: policy, dtype: int64

# %%
# 9. Get categorical features
# question is not clear: assumption: show cat features + 
customer_cat.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor        Inactives      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor        Inactives      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status        policy_type           policy  \
# 0      Suburban        Married  Corporate/special  Non-personal L3
# 1      Suburban    Not married      Personal Auto      Personal L3
# 2      Suburban        Married      Personal Auto      Personal L3
# 3      Suburban        Married  Corporate/special  Non-personal L2
# 4  Non-suburban    Not married      Personal Auto      Personal L1
#
#   renew_offer_type sales_channel  vehicle_class vehicle_size
# 0           Offer1         Agent   Two-Door Car      Medsize
# 1           Offer3         Agent  Four-Door Car      Medsize
# 2           Offer1         Agent   Two-Door Car      Medsize
# 3           Offer1   Call Center            SUV      Medsize
# 4           Offer1         Agent  Four-Door Car      Medsize

# %%
for c in customer_cat:
    print(customer_cat[c].value_counts())
    print(' ')
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master or Higher        1083
# Name: education, dtype: int64
#
# Employed     5698
# Inactives    3436
# Name: employmentstatus, dtype: int64
#
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# Suburban        5779
# Non-suburban    3355
# Name: location_code, dtype: int64
#
# Married        5298
# Not married    3836
# Name: marital_status, dtype: int64
#
# Personal Auto        6788
# Corporate/special    2346
# Name: policy_type, dtype: int64
#
# Personal L3        3426
# Personal L2        2122
# Personal L1        1240
# Non-personal L3    1162
# Non-personal L2     759
# Non-personal L1     425
# Name: policy, dtype: int64
#
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: renew_offer_type, dtype: int64
#
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: sales_channel, dtype: int64
#
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports/luxury     831
# Name: vehicle_class, dtype: int64
#
# Medsize    6424
# Small      1764
# Large       946
# Name: vehicle_size, dtype: int64

# %% [markdown]
# # Lab | Cleaning categorical data.

# %% [markdown]
# ## Instructions
# 1. Import the necessary libraries if you are starting a new notebook.
# 2. Load the continuous and discrete variables into continuous_df and discrete_df variables.
# 3. Plot a correlation matrix, what can you see?
# 4. Create a function to plot every discrete variables. Do the same with continuous variables (be careful, you may change the plot type to another one better suited for continuous data).
# 5. What can you see in the plots?
# 6. Look for outliers in the continuous variables we have found. Hint: There was a good plot to do that.
# 7. Have you found outliers? If you have, what should we do with them?
# 8. Check nan values per column.
# 9. Define a function that differentiate between continuous and discrete variables. Hint: Number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.
# 10. for the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.
# 11. Get categorical features.
# 12. What should we do with the customer id column?

# %%
# Import the necessary libraries if you are starting a new notebook.
# done

# %%
# Load the continuous and discrete variables into continuous_df and discrete_df variables.
display(customer_con.head(1))
display(customer_dis.head(1))
display(customer_cat.head(1))
# Out:
#    customer_lifetime_value effective_to_date  income  monthly_premium_auto  \
# 0              2763.519279        2011-02-24   56274                    69
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
#    number_of_open_complaints  number_of_policies
# 0                          0                   1
#         state response coverage education employmentstatus gender  \
# 0  Washington       No    Basic  Bachelor         Employed      F
#
#   location_code marital_status        policy_type           policy  \
# 0      Suburban        Married  Corporate/special  Non-personal L3
#
#   renew_offer_type sales_channel vehicle_class vehicle_size
# 0           Offer1         Agent  Two-Door Car      Medsize

# %%
# Plot a correlation matrix, what can you see?
# done

# %%
# Create a function to plot every discrete variables. Do the same with continuous 
# variables (be careful, you may change the plot type to another one better suited for continuous data).
def discrete():
    for column in customer_dis.columns:
        sns.displot(customer_dis[column])
        plt.show()
discrete()

def continuous():
    for column in customer_con.columns:
        sns.displot(customer_con[column], bins = 20)
        plt.show()
continuous()

# %%
# Look for outliers in the continuous variables we have found. Hint: There was a good plot to do that.
# Decision outliers have been made in the morning lab

# %%
# Have you found outliers? If you have, what should we do with them?
# No mentionable outliers

# %%
# Check nan values per column.
# done

# %%
# Define a function that differentiate between continuous and discrete variables. 
# Hint: Number of unique values might be useful. Store continuous data into a continuous 
# variable and do the same for discrete and categorical.
# done

# %%
# Get categorical features.
customer_cat.head(60)
# Out:
#          state response  coverage             education employmentstatus  \
# 0   Washington       No     Basic              Bachelor         Employed
# 1      Arizona       No  Extended              Bachelor        Inactives
# 2       Nevada       No   Premium              Bachelor         Employed
# 3   California       No     Basic              Bachelor        Inactives
# 4   Washington       No     Basic              Bachelor         Employed
#    renew_offer_type sales_channel  vehicle_class vehicle_size
# 0            Offer1         Agent   Two-Door Car      Medsize
# 1            Offer3         Agent  Four-Door Car      Medsize
# 2            Offer1         Agent   Two-Door Car      Medsize
# 3            Offer1   Call Center            SUV      Medsize
# 4            Offer1         Agent  Four-Door Car      Medsize
# 5            Offer2           Web   Two-Door Car      Medsize
# 6            Offer1         Agent  Four-Door Car      Medsize
# 7            Offer1         Agent  Four-Door Car      Medsize
# 8            Offer1         Agent  Four-Door Car      Medsize
# 9            Offer2        Branch  Four-Door Car      Medsize
# 10           Offer1         Agent  Four-Door Car        Small
# 11           Offer2         Agent            SUV      Medsize
# 12           Offer2         Agent  Four-Door Car      Medsize
# 13           Offer2        Branch            SUV      Medsize
# 14           Offer4   Call Center  Four-Door Car      Medsize
# 15           Offer2        Branch  Four-Door Car      Medsize
# 16           Offer2   Call Center   Two-Door Car      Medsize
# 17           Offer3   Call Center            SUV      Medsize
# 18           Offer2        Branch  Four-Door Car      Medsize
# 19           Offer1   Call Center  Four-Door Car        Small
# 20           Offer1        Branch   Two-Door Car      Medsize
# 21           Offer4   Call Center  Four-Door Car      Medsize
# 22           Offer1         Agent  Four-Door Car      Medsize
# 23           Offer1        Branch  Four-Door Car      Medsize
# 24           Offer2        Branch  Four-Door Car      Medsize
# 25           Offer2   Call Center  Four-Door Car        Large
# 26           Offer1         Agent  Four-Door Car        Small
# 27           Offer1        Branch            SUV      Medsize
# 28           Offer1   Call Center  Four-Door Car        Large
# 29           Offer2        Branch  Four-Door Car        Small
# 30           Offer4   Call Center  Four-Door Car        Small
# 31           Offer2         Agent  Sports/luxury      Medsize
# 32           Offer1   Call Center  Four-Door Car      Medsize
# 33           Offer1         Agent   Two-Door Car        Small
# 34           Offer3           Web  Four-Door Car      Medsize
# 35           Offer1        Branch  Four-Door Car      Medsize
# 36           Offer1         Agent  Four-Door Car        Small
# 37           Offer2           Web  Four-Door Car        Small
# 38           Offer3         Agent   Two-Door Car        Small
# 39           Offer1   Call Center  Four-Door Car      Medsize
# 40           Offer3   Call Center   Two-Door Car      Medsize
# 41           Offer2         Agent   Two-Door Car      Medsize
# 42           Offer2         Agent  Four-Door Car        Small
# 43           Offer4         Agent  Sports/luxury      Medsize
# 44           Offer2   Call Center  Four-Door Car        Large
# 45           Offer1        Branch            SUV      Medsize
# 46           Offer3   Call Center  Four-Door Car      Medsize
# 47           Offer4         Agent   Two-Door Car      Medsize
# 48           Offer2   Call Center  Four-Door Car      Medsize
# 49           Offer4        Branch  Four-Door Car      Medsize
# 50           Offer1         Agent            SUV        Small
# 51           Offer1           Web            SUV      Medsize
# 52           Offer4        Branch  Four-Door Car      Medsize
# 53           Offer4         Agent  Four-Door Car      Medsize
# 54           Offer1        Branch  Four-Door Car        Small
# 55           Offer3   Call Center  Four-Door Car        Small
# 56           Offer2        Branch  Four-Door Car      Medsize
# 57           Offer1   Call Center            SUV        Small
# 58           Offer1   Call Center            SUV      Medsize
# 59           Offer1         Agent  Four-Door Car      Medsize

# %%
# What should we do with the customer id column?
# drop it or save for later when needed for reporting results

# %% [markdown]
# # Lab | Feature extraction

# %% [markdown]
# ## Instructions
# 1. Open the categoricals variable we created before.
# 2. Plot all the categorical variables with the proper plot. What can you see?
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?
# 4. Plot time variable. Can you extract something from it?

# %%
# 1. Open the categoricals variable we created before.
categoricals = customer_df.select_dtypes(np.object)
categoricals.head()
# this is so unnecessary, besides we were using var customer_df in the very first question
# so better this one
customer_cat.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor        Inactives      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor        Inactives      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status        policy_type           policy  \
# 0      Suburban        Married  Corporate/special  Non-personal L3
# 1      Suburban    Not married      Personal Auto      Personal L3
# 2      Suburban        Married      Personal Auto      Personal L3
# 3      Suburban        Married  Corporate/special  Non-personal L2
# 4  Non-suburban    Not married      Personal Auto      Personal L1
#
#   renew_offer_type sales_channel  vehicle_class vehicle_size
# 0           Offer1         Agent   Two-Door Car      Medsize
# 1           Offer3         Agent  Four-Door Car      Medsize
# 2           Offer1         Agent   Two-Door Car      Medsize
# 3           Offer1   Call Center            SUV      Medsize
# 4           Offer1         Agent  Four-Door Car      Medsize

# %%
# 2. Plot all the categorical variables with the proper plot. What can you see?
# Again
for c in customer_cat:
    plt.figure(figsize=(10,5))
    plt.bar(customer_cat[c].unique(), customer_cat[c].value_counts())
    plt.title(c)
    plt.show();

# %%
# 3. There might be some columns that seem to be redundant, check their values to 
# be sure. What should we do with them?
# done

# %%
# 4. Plot time variable. Can you extract something from it?
customer_con['effective_to_date'].max()-customer_con['effective_to_date'].min()
# Out:
# Timedelta('58 days 00:00:00')

# %%
import plotly.express as px

fig = px.bar(customer_con, x='effective_to_date', y='total_claim_amount')
fig.show()
# I cannot extract anything from it: january 12th public holiday?
# Out:
# <div>                            <div id="39e1f13d-53cf-43ef-bd91-06272928d4dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39e1f13d-53cf-43ef-bd91-06272928d4dd")) {                    Plotly.newPlot(                        "39e1f13d-53cf-43ef-bd91-06272928d4dd",                        [{"alignmentgroup":"True","hovertemplate":"effective_to_date=%{x}<br>total_claim_amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["2011-02-24T00:00:00","2011-01-31T00:00:00","2011-02-19T00:00:00","2011-01-20T00:00:00","2011-02-03T00:00:00","2011-01-25T00:00:00","2011-02-24T00:00:00","2011-01-18T00:00:00","2011-01-26T00:00:00","2011-02-17T00:00:00","2011-02-21T00:00:00","2011-01-06T00:00:00","2011-02-06T00:00:00","2011-01-10T00:00:00","2011-01-18T00:00:00","2011-01-17T00:00:00","2011-02-06T00:00:00","2011-01-05T00:00:00","2011-02-27T00:00:00","2011-01-14T00:00:00","2011-02-19T00:00:00","2011-01-21T00:00:00","2011-01-26T00:00:00","2011-02-24T00:00:00","2011-02-05T00:00:00","2011-01-29T00:00:00","2011-02-28T00:00:00","2011-02-12T00:00:00","2011-02-02T00:00:00","2011-02-07T00:00:00","2011-02-28